# %%
from dputils.scrape import Scraper, Tag
from pprint import pp

# %% [markdown]
# Tag - it is a class and is used to determine what to extract from the page
#
# Scraper - it is a function which helps to extract data from the page

# %%
url = 'https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
scraper = Scraper(url)

# %%
data = scraper.get_repeating_date_from_page(
    target = Tag('div',cls='DOjaWF gdgoEp'),
    items = Tag('div', cls='_75nlfW'),
    title = Tag('div',cls='KzDlHZ'),
    price = Tag('div',cls='Nx9bqj _4b5DiR')
)

# %%
for item in data:
    pp(item)
# Out:
# {'title': 'Apple iPhone 15 (Black, 128 GB)', 'price': '₹69,999'}
# {'title': 'Apple iPhone 15 (Blue, 128 GB)', 'price': '₹69,999'}
# {'title': 'Apple iPhone 14 Plus (Blue, 128 GB)', 'price': '₹59,999'}
# {'title': 'Apple iPhone 15 (Pink, 128 GB)', 'price': '₹69,999'}
# {'title': 'Apple iPhone 14 Plus (Midnight, 128 GB)', 'price': '₹59,999'}
# {'title': 'Motorola G34 5G (Ocean Green, 128 GB)', 'price': '₹11,999'}
# {'title': 'Motorola g64 5G (Ice Lilac, 256 GB)', 'price': '₹15,999'}
# {'title': 'Motorola Edge 50 Fusion (Marshmallow Blue, 128 GB)',
#  'price': '₹22,999'}
# {'title': 'Motorola Edge 50 Fusion (Marshmallow Blue, 256 GB)',
#  'price': '₹24,999'}
# {'title': 'Motorola g04s (Concord Black, 64 GB)', 'price': '₹6,999'}
# {'title': 'Motorola g04s (Satin Blue, 64 GB)', 'price': '₹6,999'}
# {'title': 'Apple iPhone 15 (Green, 128 GB)', 'price': '₹69,999'}
# {'title': 'Motorola g64 5G (Mint Green, 256 GB)', 'price': '₹15,999'}
# {'title': 'Motorola g64 5G (Mint Green, 128 GB)', 'price': '₹13,999'}
# {'title': 'Apple iPhone 15 Plus (Blue, 128 GB)', 'price': '₹79,999'}
# {'title': 'Motorola Edge 50 Pro 5G with 68W Charger (Luxe Lavender, 256 GB)',
#  'price': '₹29,999'}
# {'title': 'Apple iPhone 13 (Midnight, 128 GB)', 'price': '₹51,999'}
# {'title': 'OPPO K12x 5G with 45W SUPERVOOC Charger In-The-Box (Midnight '
#           'Voilet, 128 GB)',
#  'price': '₹12,999'}
# {'title': 'vivo T3x 5G (Celestial Green, 128 GB)', 'price': '₹14,999'}
# {'title': 'REDMI 13C (Starshine Green, 128 GB)', 'price': '₹7,699'}
# {'title': 'vivo T3x 5G (Crimson Bliss, 128 GB)', 'price': '₹14,999'}
# {'title': 'Apple iPhone 15 Plus (Black, 128 GB)', 'price': '₹79,999'}
# {'title': 'vivo T3x 5G (Celestial Green, 128 GB)', 'price': '₹13,499'}
# {'title': 'vivo T3x 5G (Crimson Bliss, 128 GB)', 'price': '₹13,499'}

# %%
import pandas as pd

# %%
pd.DataFrame(data)
# Out:
#                                                 title    price
# 0                     Apple iPhone 15 (Black, 128 GB)  ₹69,999
# 1                      Apple iPhone 15 (Blue, 128 GB)  ₹69,999
# 2                 Apple iPhone 14 Plus (Blue, 128 GB)  ₹59,999
# 3                      Apple iPhone 15 (Pink, 128 GB)  ₹69,999
# 4             Apple iPhone 14 Plus (Midnight, 128 GB)  ₹59,999
# 5               Motorola G34 5G (Ocean Green, 128 GB)  ₹11,999
# 6                 Motorola g64 5G (Ice Lilac, 256 GB)  ₹15,999
# 7   Motorola Edge 50 Fusion (Marshmallow Blue, 128...  ₹22,999
# 8   Motorola Edge 50 Fusion (Marshmallow Blue, 256...  ₹24,999
# 9                Motorola g04s (Concord Black, 64 GB)   ₹6,999
# 10                  Motorola g04s (Satin Blue, 64 GB)   ₹6,999
# 11                    Apple iPhone 15 (Green, 128 GB)  ₹69,999
# 12               Motorola g64 5G (Mint Green, 256 GB)  ₹15,999
# 13               Motorola g64 5G (Mint Green, 128 GB)  ₹13,999
# 14                Apple iPhone 15 Plus (Blue, 128 GB)  ₹79,999
# 15  Motorola Edge 50 Pro 5G with 68W Charger (Luxe...  ₹29,999
# 16                 Apple iPhone 13 (Midnight, 128 GB)  ₹51,999
# 17  OPPO K12x 5G with 45W SUPERVOOC Charger In-The...  ₹12,999
# 18              vivo T3x 5G (Celestial Green, 128 GB)  ₹14,999
# 19                REDMI 13C (Starshine Green, 128 GB)   ₹7,699
# 20                vivo T3x 5G (Crimson Bliss, 128 GB)  ₹14,999
# 21               Apple iPhone 15 Plus (Black, 128 GB)  ₹79,999
# 22              vivo T3x 5G (Celestial Green, 128 GB)  ₹13,499
# 23                vivo T3x 5G (Crimson Bliss, 128 GB)  ₹13,499

# %%
url = 'https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off'
scraper = Scraper(url)

# %%
data1 = scraper.get_repeating_date_from_page(
    target = Tag('div',cls='nt6sNV JxFEK3 _48O0EI'),
    items = Tag('div', cls='_75nlfW'),
    title = Tag('div',cls='KzDlHZ'),
    price = Tag('div',cls='Nx9bqj _4b5DiR')
)

# %%
for item in data1:
    pp(item)
# Out:
# {'title': 'Thomson NEO Core Series Intel Core i5 12th Gen 1235U - (8 GB/512 GB '
#           'SSD/Windows 11 Home) IN-N15I Thin ...',
#  'price': '₹36,990'}
# {'title': 'CHUWI Intel Core i5 10th Gen 1035G1 - (16 GB/512 GB SSD/Windows 11 '
#           'Home) CoreBook X Grey Laptop',
#  'price': '₹24,990'}
# {'title': 'Acer One (2024) Intel Core i3 11th Gen 1115G4 - (8 GB/512 GB '
#           'SSD/Windows 11 Home) AO 14 Z 8-415 Thin a...',
#  'price': '₹22,990'}
# {'title': 'SAMSUNG Galaxy Book4 Intel Core i5 13th Gen 1335U - (16 GB/512 GB '
#           'SSD/Windows 11 Home) NP750XGJ-KG2IN ...',
#  'price': '₹61,990'}
# {'title': 'ASUS Vivobook 15 (2024) Intel Core i3 12th Gen 1215U - (8 GB/512 GB '
#           'SSD/Windows 11 Home) X1502ZA-EJ953...',
#  'price': '₹33,990'}
# {'title': 'Acer Aspire 7 (2024) Intel Core i5 12th Gen 12450H - (16 GB/512 GB '
#           'SSD/Windows 11 Home/4 GB Graphics/N...',
#  'price': '₹49,990'}
# {'title': 'HP Intel Core i5 12th Gen 1235U - (16 GB/512 GB SSD/Windows 11 '
#           'Home) 15s-fq5330TU|15-fd0111TU Thin and...',
#  'price': '₹50,800'}
# {'title': 'Acer Chromebook Plus (2024) Intel Core i3 N305 - (8 GB/256 GB '
#           'SSD/Chrome OS) CB514-4H-39T7 Chromebook',
#  'price': '₹24,990'}
# {'title': 'Acer Aspire 3 Backlit Intel Core i5 12th Gen 1235U - (16 GB/512 GB '
#           'SSD/Windows 11 Home) A324-51 Thin a...',
#  'price': '₹39,990'}
# {'title': 'HP AMD Ryzen 5 Hexa Core 5500U - (16 GB/512 GB SSD/Windows 11 Home) '
#           '15s- eq2182AU Thin and Light Lapto...',
#  'price': '₹40,990'}
# {'title': 'Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 12450H - (16 GB/512 GB '
#           'SSD/Windows 11 Home) 14IAH8 Thin a...',
#  'price': '₹50,490'}
# {'title': 'HP Intel Core N N305 - (8 GB/256 GB/Chrome Plus) 14b-cd0014TU '
#           'Chromebook',
#  'price': '₹50,490'}
# {'title': 'HP AMD Ryzen 3 Quad Core 5300U - (8 GB/512 GB SSD/Windows 11 Home) '
#           '15s-eq2143au Thin and Light Laptop',
#  'price': '₹29,990'}
# {'title': 'Apple 2020 Macbook Air Apple M1 - (8 GB/256 GB SSD/Mac OS Big Sur) '
#           'MGN63HN/A',
#  'price': '₹67,990'}
# {'title': 'HP Intel Core i3 12th Gen 1215U - (16 GB/512 GB SSD/Windows 11 '
#           'Home) 15s-fy5004TU Thin and Light Lapto...',
#  'price': '₹37,990'}
# {'title': 'Acer Swift Go 14 (2024) EVO OLED Intel Core i5 13th Gen 13500H - '
#           '(16 GB/512 GB SSD/Windows 11 Home) SF...',
#  'price': '₹56,990'}
# {'title': 'Thomson Intel Celeron Dual Core N4020 - (4 GB/128 GB SSD/Windows 11 '
#           'Home) IN-PX14C Thin and Light Lapt...',
#  'price': '₹16,490'}
# {'title': 'Lenovo IdeaPad Slim 3 (2024) Intel Core i3 12th Gen 1215U - (8 '
#           'GB/512 GB SSD/Windows 11 Home) 15IAU7 T...',
#  'price': '₹35,490'}
# {'title': 'Acer Aspire 3 Intel Core i3 12th Gen 1215U - (8 GB/512 GB '
#           'SSD/Windows 11 Home) A324-51 Thin and Light ...',
#  'price': '₹27,990'}
# {'title': 'ASUS Vivobook 15, with Backlit Keyboard, Intel Core i5 12th Gen '
#           '1235U - (16 GB/512 GB SSD/Windows 11 H...',
#  'price': '₹48,990'}
# {'title': 'CHUWI Intel Celeron Dual Core 10th Gen N4020 - (4 GB/128 GB '
#           'SSD/Windows 11 Home) HeroBook Air Laptop',
#  'price': '₹13,990'}
# {'title': 'Thomson NEO Core Series Intel Core i3 12th Gen 1215U - (8 GB/256 GB '
#           'SSD/Windows 11 Home) IN-N15I Thin ...',
#  'price': '₹27,490'}
# {'title': 'SAMSUNG Galaxy Book4 Intel Core i5 13th Gen 1335U - (8 GB/512 GB '
#           'SSD/Windows 11 Home) NP750XGJ-KG1IN /...',
#  'price': '₹56,990'}
# {'title': 'DELL Inspiron 3520 Intel Core i3 12th Gen 1215U - (8 GB/512 GB '
#           'SSD/Windows 11 Home) New Inspiron 15 La...',
#  'price': '₹35,990'}

# %%
pd.DataFrame(data1)
# Out:
#                                                 title    price
# 0   Thomson NEO Core Series Intel Core i5 12th Gen...  ₹36,990
# 1   CHUWI Intel Core i5 10th Gen 1035G1 - (16 GB/5...  ₹24,990
# 2   Acer One (2024) Intel Core i3 11th Gen 1115G4 ...  ₹22,990
# 3   SAMSUNG Galaxy Book4 Intel Core i5 13th Gen 13...  ₹61,990
# 4   ASUS Vivobook 15 (2024) Intel Core i3 12th Gen...  ₹33,990
# 5   Acer Aspire 7 (2024) Intel Core i5 12th Gen 12...  ₹49,990
# 6   HP Intel Core i5 12th Gen 1235U - (16 GB/512 G...  ₹50,800
# 7   Acer Chromebook Plus (2024) Intel Core i3 N305...  ₹24,990
# 8   Acer Aspire 3 Backlit Intel Core i5 12th Gen 1...  ₹39,990
# 9   HP AMD Ryzen 5 Hexa Core 5500U - (16 GB/512 GB...  ₹40,990
# 10  Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 1...  ₹50,490
# 11  HP Intel Core N N305 - (8 GB/256 GB/Chrome Plu...  ₹50,490
# 12  HP AMD Ryzen 3 Quad Core 5300U - (8 GB/512 GB ...  ₹29,990
# 13  Apple 2020 Macbook Air Apple M1 - (8 GB/256 GB...  ₹67,990
# 14  HP Intel Core i3 12th Gen 1215U - (16 GB/512 G...  ₹37,990
# 15  Acer Swift Go 14 (2024) EVO OLED Intel Core i5...  ₹56,990
# 16  Thomson Intel Celeron Dual Core N4020 - (4 GB/...  ₹16,490
# 17  Lenovo IdeaPad Slim 3 (2024) Intel Core i3 12t...  ₹35,490
# 18  Acer Aspire 3 Intel Core i3 12th Gen 1215U - (...  ₹27,990
# 19  ASUS Vivobook 15, with Backlit Keyboard, Intel...  ₹48,990
# 20  CHUWI Intel Celeron Dual Core 10th Gen N4020 -...  ₹13,990
# 21  Thomson NEO Core Series Intel Core i3 12th Gen...  ₹27,490
# 22  SAMSUNG Galaxy Book4 Intel Core i5 13th Gen 13...  ₹56,990
# 23  DELL Inspiron 3520 Intel Core i3 12th Gen 1215...  ₹35,990
